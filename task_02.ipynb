# %% [markdown]
# # Задания для самостоятельного выполнения (блок 2, условные выражения)

# %% [markdown]
# <a href="https://colab.research.google.com/github/dm-fedorov/python_basic/blob/master/task_02.ipynb" target="_blank"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# ## Задание 1
#
# Напишите в отдельном файле программу, которая по коду города и длительности переговоров вычисляет их стоимость и результат выводит на экран:
#
# - Екатеринбург: код 343, 15 руб/мин
# - Омск: код 381, 18 руб/мин
# - Воронеж: код 473, 13 руб/мин

# %%
# здесь решение

# %% [markdown]
# ## Задание 2
#
# Напишите программу в отдельном файле для определения стоимости билетов в кино с учетом скидок.
#
# **Скидки**
# - При покупке билетов за день до сеанса: скидка 5%.
# - Вы можете купить билет со скидкой 20%. Для этого нужно собрать. компанию не менее 20 человек.
#
# и, да, скидки суммируются :-)
#
# Порядок действий:
# - выбрать фильм
# - выбрать дату (сегодня, завтра)
# - выбрать время
# - указать количество билетов
# - определить стоимость
#
# **Исходные данные**
# - Фильм "Паразиты", сеансы: 12 часов – 250 руб, 16 – 350 руб, 20 – 450 руб.
# - Фильм "1917", сеансы: 10 часов – 250 руб, 13 – 350 руб, 16 – 350 руб.
# - Фильм "Соник в кино", сеансы: 10 часов – 350 руб, 14 – 450 руб, 18 – 450 руб.
#
# Пример выполнения программы:
#
# ```
# =========================================================================
#
# Программа для подсчета стоимости билетов в кино.
# Выбрать фильм: Пятница
# Выбрать день (сегодня, завтра): завтра
# Выбрать время: 12
# Выбрать количество билетов: 12
# Выбрали фильм: Пятница День: завтра Время: 12 Количество билетов: 12
# Результат: 2850.0 руб.
#
# =========================================================================
#
# Программа для подсчета стоимости билетов в кино.
# Выбрать фильм: 8
# Выбрать день (сегодня, завтра): 5
# Выбрать время: 5
# Выбрать количество билетов: 4
# Выбрали фильм: 8 День: 5 Время: 5 Количество билетов: 4
# Ошибка ввода.
# ```

# %%
# здесь решение
