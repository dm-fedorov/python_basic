# %%
import requests

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.text, 'lxml')

# %%
# soup

# %%
#print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js bg-fixed" lang="" style="background-image:url(https://nplus1.ru/images/2021/03/28/79673eb88a3c1aed2e7618631f87ed3f.jpg)">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="7991d7eb02d759f05b9050e111a7e3eb" name="wmail-verification"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <title>
#    N+1: научные статьи, новости, открытия
#   </title>
#   <!-- for Google -->
#   <meta content="N+1: научные статьи, новости, открытия" name="description"/>
#   <meta content="" name="author"/>
#   <meta content="" name="copyright"/>
#   <!-- for Facebook -->
#   <meta content="N+1: научные статьи, новости, открытия" property="og:title"/>
#   <meta content="https://nplus1.ru/i/logo.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N+1: научные статьи, новости, открытия" property="og:description"/>
#   <!-- for Twitter -->
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N+1: научные статьи, новости, открытия" name="twitter:title"/>
#   <meta content="N+1: научные статьи, новости, открытия" name="twitter:description"/>
#   <meta content="https://nplus1.ru/i/logo.png" name="twitter:image"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <link href="/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/css/main.min.css?v=1615958639" rel="stylesheet"/>
#   <link href="/css/desktop.min.css?v=1452887696" rel="stylesheet"/>
#   <link href="/css/tablet.min.css?v=1499281342" rel="stylesheet"/>
#   <link href="/css/mobile.min.css?v=1603187018" rel="stylesheet"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js">
#   </script>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js">
#   </script>
#   <script src="/js/lib/adfox.asyn.code.ver3.js" type="text/javascript">
#   </script>
#   <script src="/js/lib/adfox.asyn.code.scroll.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js">
#   </script>
#   <script async="" id="__lxGc__rtr" src="//s.clickiocdn.com/t/195458/360.js" type="text/javascript">
#   </script>
#   <script async="" src="//s.luxupcdnc.com/t/common_402.js" type="text/javascript">
#   </script>
#   <!--  ad -->
#   <script type="text/javascript">
#    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
#   </script>
#   <!-- /ad -->
#   <script type="application/ld+json">
#    { "@context": "http://schema.org", "@type": "WebSite", "url": "https://nplus1.ru", "name": "N+1: научные статьи, новости, открытия", "description": "N+1: научные статьи, новости, открытия", "image": "https://nplus1.ru/i/logo.png", "publisher": { "@type": "Organization", "name": "N+1", "logo": { "@type":"ImageObject", "url": "https://nplus1.ru/i/logo-alt.png" }, "sameAs": [ "https://www.facebook.com/nplusone", "https://twitter.com/nplusodin", "https://vk.com/nplusone", "https://ok.ru/nplus1", "https://soundcloud.com/nplus_1", "https://t.me/nplusone" ] }, "potentialAction":{ "@type":"SearchAction", "target":"https://nplus1.ru/search?q={search_term_string}", "query-input":"required name=search_term_string" } }
#   </script>
#  </head>
#  <body class="_main" style="background-image:url(https://nplus1.ru/images/2021/03/28/79673eb88a3c1aed2e7618631f87ed3f.jpg)">
#   <link href="//s.luxupcdnc.com/cp/all/cookies_policy.css" property="" rel="stylesheet"/>
#   <script type="text/javascript">
#    _cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};
#   </script>
#   <script async="" src="//s.luxupcdnc.com/cp/all/cookies_policy.js" type="text/javascript">
#   </script>
#   <div id="viewport">
#    <div id="shadow">
#    </div>
#    <div class="ad ad-top">
#     <!-- bh1 -->
#     <!--AdFox START-->
#     <!--nplus1_dir-->
#     <!--Площадка: https://nplus1.ru/ / * / *-->
#     <!--Тип баннера: Верхняя перетяжка 100%-->
#     <!--Расположение: <верх страницы>-->
#     <div id="adfox_15000335664353901">
#     </div>
#     <script>
#      window.Ya.adfoxCode.create({
#         ownerId: 248569,
#         containerId: 'adfox_15000335664353901',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fqtd',
#             puid1: ''
#         }
#     });
#     </script>
#    </div>
#    <header id="header-mobile">
#     <div class="container">
#      <a class="action-menu pull-left" href="#">
#       <i class="icon icon-navicon">
#       </i>
#      </a>
#      <a class="link-logo" href="/">
#       <img src="/i/logo-mobile.png"/>
#      </a>
#      <a class="action-search pull-right" href="#">
#       <i class="icon icon-search">
#       </i>
#      </a>
#      <form action="/search" class="form-search" method="get">
#       <div class="control">
#        <input name="q" placeholder="Найти" type="text" value=""/>
#       </div>
#       <a class="action-search-close" href="#">
#        ×
#       </a>
#      </form>
#     </div>
#     <nav class="nav-rubrics">
#      <ul>
#       <li>
#        <a class="" href="/rubric/astronomy">
#         Астрономия
#        </a>
#       </li>
#       <li>
#        <a class="" href="/rubric/physics">
#         Физика
#        </a>
#       </li>
#       <li>
#        <a class="" href="/rubric/biology">
#         Биология
#        </a>
#       </li>
#       <li>
#        <a class="" href="/rubric/robots-drones">
#         Роботы и дроны
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/explainatorium">
#         Давайте разберемся
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/bookshelf">
#         Книжная полка
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/Courses">
#         Курсы
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/coronavirus-history">
#         Коронавирусные хроники
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </header>
#    <div class="js-mediator-container" id="layout">
#     <!-- header -->
#     <header class="_middle" id="header">
#      <div class="row">
#       <div class="col col-logo">
#        <a class="link-logo" href="/">
#        </a>
#       </div>
#       <div class="col col-nav-main">
#        <form action="/search" class="form-search" method="get">
#         <div class="control">
#          <input name="q" placeholder="Найти" type="text" value=""/>
#         </div>
#         <a class="action-search-close" href="#">
#          ×
#         </a>
#        </form>
#        <nav class="nav-rubrics">
#         <ul>
#          <li>
#           <a class="" href="/rubric/astronomy">
#            Астрономия
#           </a>
#          </li>
#          <li>
#           <a class="" href="/rubric/physics">
#            Физика
#           </a>
#          </li>
#          <li>
#           <a class="" href="/rubric/biology">
#            Биология
#           </a>
#          </li>
#          <li>
#           <a class="" href="/rubric/robots-drones">
#            Роботы и дроны
#           </a>
#          </li>
#          <li>
#           <a class="action-search" href="#">
#            <i class="icon icon-search">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <nav class="nav-themes">
#         <ul>
#          <li data-name="explainatorium">
#           <a class="" href="/theme/explainatorium">
#            Давайте разберемся
#           </a>
#          </li>
#          <li data-name="bookshelf">
#           <a class="" href="/theme/bookshelf">
#            Книжная полка
#           </a>
#          </li>
#          <li data-name="Courses">
#           <a class="" href="/theme/Courses">
#            Курсы
#           </a>
#          </li>
#          <li data-name="coronavirus-history">
#           <a class="" href="/theme/coronavirus-history">
#            Коронавирусные хроники
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <div class="container line-up">
#       <div class="line line-second">
#        <a class="action-line-toggle" href="https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there">
#         <div class="heading">
#          <span>
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there">
#         <div class="heading">
#          <span>
#           Давайте разберемся
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Здравствуй, гхола: чего ждать от нового метода клонирования людей
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/17/russian-hajj">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Айлин Кейн «Российский хадж. Империя и паломничество в Мекку»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/16/russian-small-towns">
#         <div class="heading">
#          <span>
#           Terra Cognita
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Жить или выживать: география малых городов России
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/04/mesmerism-and-the-end-of-the-enlightenment">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Роберт Дарнтон «Месмеризм и конец эпохи Просвещения во Франции»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/02/astronomer-Subbotina">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Ольга Валькова «Жизнь и удивительные приключения астронома Субботиной»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/02/march-2021-observations">
#         <div class="heading">
#          <span>
#           Космические дневники
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Что наблюдать на небе в марте: соединение Марса и Плеяд, утренний Меркурий
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/01/freezing-warming">
#         <div class="heading">
#          <span>
#           И о погоде
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Холодное дыхание глобального потепления: как февральские морозы связаны с теплой Арктикой
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/02/26/arctic-ice">
#         <div class="heading">
#          <span>
#           Terra Cognita
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Лед тронулся: чем грозят изменения климата в Арктике
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/02/26/the-undercover-economist">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Тим Харфорд «Экономист под прикрытием»
#          </span>
#         </div>
#        </a>
#        <a class="container-link active" href="https://nplus1.ru/blog/2021/03/22/contrtaunt">
#         <div class="heading">
#          <span>
#           Эксперименты
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Первое слово съела корова: а какие отговорки помните вы?
#          </span>
#         </div>
#        </a>
#       </div>
#      </div>
#     </header>
#     <!-- /header -->
#     <!--  hero -->
#     <!-- /hero -->
#     <!-- main section -->
#     <section id="main">
#      <!--   dynamic content -->
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap _indent-bottom-no" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <div class="col col-2" data-adaptive="1" data-mobile-toggle="col-2 col-1">
#        <article class="item item-main item-main- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/29/9dcc3a0623c4e38a3103bf955ad4ff3f.jpg)">
#         <a data-id="28528" href="/news/2021/03/29/ever-given">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-29">
#             10:11
#            </span>
#           </div>
#           <h3>
#            Контейнеровоз «Эвер Гивен» удалось сдвинуть с места
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 col-ad-prev" data-adaptive="1" data-middle-class="_swap col-1 _indent-bottom">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28526" href="/news/2021/03/29/insect-plant-gene">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-29">
#             09:48
#            </span>
#           </div>
#           <h3>
#            Биологи впервые обнаружили горизонтальный перенос генов от растения к насекомому
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28525" href="/news/2021/03/27/new-horizons-new-objects">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-27">
#             27 марта
#            </span>
#           </div>
#           <h3>
#            Зонд New Horizons в мае изучит на расстоянии три объекта Пояса Койпера
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28524" href="/news/2021/03/27/teeth-cold-pain">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-27">
#             27 марта
#            </span>
#           </div>
#           <h3>
#            Ионный канал TRPC5 заставил зубы болеть от холода
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 _tablet-hidden col-ad" data-adaptive="1" data-middle-class="col-1 _swap _indent-bottom" data-mobile-class="col-1 _indent-bottom">
#        <div class="ad ad-col border">
#        </div>
#       </div>
#       <div class="col col-1 col-ad-next" data-adaptive="1" data-middle-class="col-full _indent-bottom-no">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28522" href="/news/2021/03/27/encelad-ocean-circulation">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-27">
#             27 марта
#            </span>
#           </div>
#           <h3>
#            Планетологи заподозрили существование течений в подледном океане Энцелада
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28523" href="/news/2021/03/27/apophis">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-27">
#             27 марта
#            </span>
#           </div>
#           <h3>
#            Астрономы исключили риск столкновения Земли с Апофисом на 100 лет вперед
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28521" href="/news/2021/03/27/prigglitz-gasteil">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-27">
#             27 марта
#            </span>
#           </div>
#           <h3>
#            Альпийские рудокопы бронзового века полагались на доставку продуктов из соседних поселений
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <!--  fixed 8 -->
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/03/26/6b22145e09b881e2ff76700d4567e314.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/26/a4aa41fe307cae81426fe2755dd5aac2.jpg)">
#         <a data-id="28517" href="/material/2021/03/28/degray-eagle-killings">
#          <div class="caption">
#           <h3>
#            Смерть от воды
#           </h3>
#           <p class="subtitle">
#            Биологи четверть века искали убийцу орланов в Арканзасе — и, наконец, нашли
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/ecology">
#             Экология и климат
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/03/23/bd888efb442b9a7bcc7d6f6f4eabeb17.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/23/87c2292404e89357ba610ce3775c0821.jpg)">
#         <a data-id="28471" href="/material/2021/03/28/future-with-microsoft-1">
#          <div class="caption">
#           <h3>
#            Гости из будущего
#           </h3>
#           <p class="subtitle">
#            Фантазируем о том, какие новые профессии в скором (или не очень) времени будут осваивать программисты
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/partners">
#             Партнерский материал
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <!-- /fixed 8 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28519" href="/news/2021/03/26/rover-goes-worldwide">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Яндекс запустит доставку роботами еще в трех странах
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28518" href="/news/2021/03/26/leopards-mother-with-three-cubs">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Видеоловушка запечатлела самку дальневосточного леопарда с тремя детенышами
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28520" href="/news/2021/03/26/rabbits-on-forelimbs">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Биологи определили кроличий ген хождения на передних лапах
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28513" href="/news/2021/03/26/digit">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Человекоподобный робот Digit стал автономным
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28512" href="/news/2021/03/26/elephants-in-trouble">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            МСОП признал африканских слонов двумя разными видами. Оба они быстро вымирают
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28515" href="/news/2021/03/26/ssb-neurons">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            После деления в нейронах оказалось много одноцепочечных разрывов ДНК
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!--  fixed 15 -->
#       <div class="col col-1" data-adaptive="1">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/22/0b71852f663e030a2e77efc1cb5d3952.gif)">
#         <a data-id="28475" href="/blog/2021/03/22/contrtaunt">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Антропология/Эксперименты
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/12/29/e0e092ebf20ed635922f97cff3d2b808.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              Илья Ферапонтов
#             </p>
#             <p class="specs">
#              Главред
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             В словесном арсенале каждого ребенка, помимо средств нападения — способов обозвать и опозорить соперника, есть и средства защиты, которые нивелируют или даже обращают на соперника предпринятую тем словесную атаку.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 15 -->
#       <!--  fixed 16 -->
#       <div class="col col-1 _swap" data-adaptive="1" data-middle-swap="0">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/17/6cf0899bb52ecfae3a8a63eeb1c4ab8c.gif)">
#         <a data-id="28433" href="/blog/2021/03/18/tleilaxu-clones-almost-there">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Биология/Давайте разберемся
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2019/10/14/7b9ee76c6266b1d85719e0911f6986c0.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              Полина Лосева
#             </p>
#             <p class="specs">
#              Редактор
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             Во вселенной Дюны, чтобы сделать гхолу — клона — вам нужны были только клетки человека и специальные аксолотль-чаны Бене Тлейлаксу. На этой неделе опубликовано сразу три статьи, авторы которых сделали первый шаг в этом направлении: им не нужны больше ни перенос ядра, ни чужие бластоцисты.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 16 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <!--  fixed 17 -->
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/03/25/c25803b99adbe3da2b4da9c4642c3db8.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/27/12b82ca5f0cfcce1a5cbc471ddbcf5bb.gif)">
#         <a data-id="28506" href="/material/2021/03/26/gulfstream-and-freezing-europe">
#          <div class="caption">
#           <h3>
#            Атлантическая циркулярка
#           </h3>
#           <p class="subtitle">
#            Замерзнет ли Европа без Гольфстрима?
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/ecology">
#             Экология и климат
#            </a>
#           </li>
#           <li>
#            <a class="link-theme" href="/theme/spcweather">
#             И о погоде
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/03/24/49f487ddaa5838d5d2af7ceb9f329f64.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/24/deae8feb2a4a783a0f5b56b6c240f605.jpg)">
#         <a data-id="28496" href="/material/2021/03/24/covid-vs-flu">
#          <div class="caption">
#           <h3>
#            Грипп отменяется?
#           </h3>
#           <p class="subtitle">
#            Куда пропал «сезон простуд» во время пандемии ковида и ждать ли его обратно
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/medicine">
#             Медицина
#            </a>
#           </li>
#           <li>
#            <a class="link-theme" href="/theme/coronavirus-history">
#             Коронавирусные хроники
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <!-- /fixed 17 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28516" href="/news/2021/03/26/vixen">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Британцы обзаведутся палубными беспилотниками
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28509" href="/news/2021/03/26/hot-jupiters-new">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Роботизированный телескоп нашел три горячих юпитера с распухшими атмосферами
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28510" href="/news/2021/03/26/nuna-development">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            Анализ цирконов указал на низкую роль тектоники плит в формировании древнего суперконтинента
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28511" href="/news/2021/03/26/angara-a5">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            В России началось серийное производство тяжелой ракеты «Ангара-А5»
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28488" href="/news/2021/03/26/outflows-young-stars-hubble">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-26">
#             26 марта
#            </span>
#           </div>
#           <h3>
#            «Хаббл» уменьшил роль джетов в остановке роста протозвезд
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="28508" href="/news/2021/03/25/atomic-clock-comparison">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2021-03-25">
#             25 марта
#            </span>
#           </div>
#           <h3>
#            Частоту атомных часов сравнили с рекордной точностью
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!--  fixed 24 -->
#       <div class="col col-1">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/17/2173e4e647e9bc8e59cfef93351c38c7.jpg)">
#         <a data-id="28424" href="/blog/2021/03/17/russian-hajj">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Ex libris/Книжная полка
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2019/02/26/688309b674c59cc08a4e1980eda70321.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              НЛО
#             </p>
#             <p class="specs">
#              Книжное издательство
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             Поддерживая хадж, Россия не просто старалась контролировать паломничество. Скорее она хваталась за новые — созданные имперскими завоеваниями — возможности, чтобы подключиться к глобальной исламской сети и превратить хадж в механизм имперской интеграции.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 24 -->
#       <!--  fixed 25 -->
#       <div class="col col-1 _swap" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-middle-swap="0">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/16/5b094815d7380247d2d1db59c6527a2d.jpg)">
#         <a data-id="28405" href="/blog/2021/03/16/russian-small-towns">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Подкасты/Terra Cognita
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2021/01/14/14e28958f4a3d6147d8cc5e89c467377.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              Terra Cognita
#             </p>
#             <p class="specs">
#              Географический подкаст
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             В России больше 1100 городов, из них 70 процентов — это города с населением меньше 50 тысяч человек. Крупные города по всему миру имеют много общего: в каждом вы наверняка найдете «Макдональдс» или «Старбакс». А вот малые города — очень разные.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 25 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <!--  fixed 26 -->
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/03/22/c1ea1ca330ac4e100fcd7579f10599b9.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/22/6b591a5f2cb449db8c3a47c4423888b1.jpg)">
#         <a data-id="28470" href="/material/2021/03/23/worldnaturephotographyawards2020">
#          <div class="caption">
#           <h3>
#            Нащелкали
#           </h3>
#           <p class="subtitle">
#            Опадающие кипарисы, улыбающаяся рыба-попугай, целеустремленная лиса в лесу
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-theme" href="/theme/bellezza">
#             Красота
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/03/15/5ffdbb2a40f09a02e558b3526e88707a.gif" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/03/15/10253c4a8aacd1d343f1a4a06488e1a0.gif)">
#         <a data-id="28352" href="/material/2021/03/19/how-do-you-want-your-eggs">
#          <div class="caption">
#           <h3>
#            Терпение, спокойствие, сейчас они появятся
#           </h3>
#           <p class="subtitle">
#            Кофе и яйца — как простой завтрак связан с фундаментальной наукой
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/partners">
#             Партнерский материал
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <!-- /fixed 26 -->
#      </div>
#      <!-- / dynamic content -->
#     </section>
#     <!-- / main section -->
#     <div id="wrapper-footer">
#      <section class="_middle" id="difficult">
#       <!-- Slider main container -->
#       <div class="swiper-container">
#        <!-- Additional required wrapper -->
#        <div class="swiper-wrapper">
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             8.8
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/23/bremsstrahlung">
#            Суперпозиция электронного состояния изменила свойства тормозного излучения
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             7.8
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/material/2021/03/26/gulfstream-and-freezing-europe">
#            Атлантическая циркулярка
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             7.8
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/25/clamp-your-rna">
#            Эффективный полимеразный рибозим подкрепил гипотезу мира РНК
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             6.1
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/24/B-meson-decay">
#            B-мезон предпочел распадаться на электроны вместо мюонов
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             5.9
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/26/ssb-neurons">
#            После деления в нейронах оказалось много одноцепочечных разрывов ДНК
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             5.8
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/24/aging-zero">
#            В зародышах млекопитающих нашли признаки омоложения сразу после оплодотворения
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             5.2
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/25/atomic-clock-comparison">
#            Частоту атомных часов сравнили с рекордной точностью
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             4.8
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/material/2021/03/28/degray-eagle-killings">
#            Смерть от воды
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             4.7
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/material/2021/03/24/covid-vs-flu">
#            Грипп отменяется?
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             4.6
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2021/03/22/flow-lines">
#            Человекоподобных роботов выдали слишком простые движения кожи лица
#           </a>
#          </h3>
#         </div>
#        </div>
#        <!-- If we need pagination -->
#        <div class="swiper-pagination">
#        </div>
#        <div class="swiper-button-prev">
#        </div>
#        <div class="swiper-button-next">
#        </div>
#       </div>
#       <h6>
#        Самое сложное
#       </h6>
#      </section>
#      <div class="container">
#       <div class="line">
#        <a class="action-line-toggle" href="https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there">
#         <div class="heading">
#          <span>
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there">
#         <div class="heading">
#          <span>
#           Давайте разберемся
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Здравствуй, гхола: чего ждать от нового метода клонирования людей
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/17/russian-hajj">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Айлин Кейн «Российский хадж. Империя и паломничество в Мекку»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/16/russian-small-towns">
#         <div class="heading">
#          <span>
#           Terra Cognita
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Жить или выживать: география малых городов России
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/04/mesmerism-and-the-end-of-the-enlightenment">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Роберт Дарнтон «Месмеризм и конец эпохи Просвещения во Франции»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/02/astronomer-Subbotina">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Ольга Валькова «Жизнь и удивительные приключения астронома Субботиной»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/02/march-2021-observations">
#         <div class="heading">
#          <span>
#           Космические дневники
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Что наблюдать на небе в марте: соединение Марса и Плеяд, утренний Меркурий
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/03/01/freezing-warming">
#         <div class="heading">
#          <span>
#           И о погоде
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Холодное дыхание глобального потепления: как февральские морозы связаны с теплой Арктикой
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/02/26/arctic-ice">
#         <div class="heading">
#          <span>
#           Terra Cognita
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Лед тронулся: чем грозят изменения климата в Арктике
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2021/02/26/the-undercover-economist">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Тим Харфорд «Экономист под прикрытием»
#          </span>
#         </div>
#        </a>
#        <a class="container-link active" href="https://nplus1.ru/blog/2021/03/22/contrtaunt">
#         <div class="heading">
#          <span>
#           Эксперименты
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Первое слово съела корова: а какие отговорки помните вы?
#          </span>
#         </div>
#        </a>
#       </div>
#      </div>
#      <script async="" src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR">
#      </script>
#      <script>
#       window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "main",
#     page_language: "ru"
# });
#      </script>
#      <div class="ad ad-col border">
#      </div>
#      <!-- footer -->
#      <footer id="footer">
#       <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#        <div class="col col-logo">
#         <a class="link-logo" href="/">
#          <img src="/i/logo-alt.png"/>
#         </a>
#        </div>
#        <div class="col col-footer-desc">
#         <nav class="nav-pages">
#          <ul>
#           <li>
#            <a href="/about">
#             О нас
#            </a>
#           </li>
#           <li>
#            <a href="/adv">
#             Рекламодателям
#            </a>
#           </li>
#           <li>
#            <a href="/rules">
#             Наши материалы
#            </a>
#           </li>
#           <li>
#            <a href="/vacancy">
#             Вакансии
#            </a>
#           </li>
#           <li>
#            <a href="/difficult">
#             Сложность
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="desc">
#          <p>
#           © 2021 N+1 Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614
#          </p>
#          <p>
#           Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru
#          </p>
#          <p>
#           Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.
#          </p>
#          <p>
#           Сайт может содержать контент, не предназначенный для лиц младше 18 лет.
#          </p>
#          <p>
#           <a class="pd" href="https://nplus1.ru/personal-data-policy">
#            Политика обработки персональных данных пользователей сайта
#           </a>
#          </p>
#          <p>
#           <script async="" src="//s.luxupcdnc.com/t/consent_195458.js" type="text/javascript">
#           </script>
#           <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">
#            Change privacy settings
#           </a>
#          </p>
#          <p>
#          </p>
#         </div>
#        </div>
#        <div class="col col-1 pull-right">
#         <nav class="nav-social">
#          <ul>
#           <li>
#            <a href="https://t.me/nplusone">
#             <i class="fa fa-telegram">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="http://vk.com/nplusone">
#             <i class="fa fa-vk">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.facebook.com/nplusone">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://twitter.com/nplusodin">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://ok.ru/nplus1">
#             <i class="fa fa-odnoklassniki">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://soundcloud.com/nplus_1">
#             <i class="fa fa-soundcloud">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="/rss">
#             <i class="fa fa-rss">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="partners">
#          <!-- Rating@Mail.ru counter -->
#          <script type="text/javascript">
#           var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
#          </script>
#          <noscript>
#           <div>
#            <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;"/>
#           </div>
#          </noscript>
#          <!-- //Rating@Mail.ru counter -->
#         </div>
#        </div>
#       </div>
#      </footer>
#      <!-- / footer -->
#     </div>
#    </div>
#   </div>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <noscript>
#    <div>
#     <img alt="" src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <script src="/js/lib/js.cookie.js">
#   </script>
#   <script src="/js/lib/jquery.swap.js">
#   </script>
#   <script src="/js/lib/swiper.jquery.min.js">
#   </script>
#   <script src="/js/lib/svg.js">
#   </script>
#   <script src="/js/lib/jquery.mobile-events.min.js">
#   </script>
#   <script src="/js/lib/social-likes.min.js">
#   </script>
#   <script src="/js/lib/jquery.sticky.js">
#   </script>
#   <!--   project scripts -->
#   <script src="/js/main.min.js?v=1592278962">
#   </script>
#   <!-- / project scripts -->
#   <!-- Quantcast Tag -->
#   <script type="text/javascript">
#    var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
#   </script>
#   <noscript>
#    <div style="display:none;">
#     <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" width="1"/>
#    </div>
#   </noscript>
#   <!-- End Quantcast tag -->
#  </body>
# </html>

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`. Посмотрим на кусочки кода, соответствующие всем ссылкам на главной странице сайта:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #
# /
# #
# #
# /rubric/astronomy
# /rubric/physics
# /rubric/biology
# /rubric/robots-drones
# /theme/explainatorium
# /theme/bookshelf
# /theme/Courses
# /theme/coronavirus-history
# /
# #
# /rubric/astronomy
# /rubric/physics
# /rubric/biology
# /rubric/robots-drones
# #
# /theme/explainatorium
# /theme/bookshelf
# /theme/Courses
# /theme/coronavirus-history
# https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there
# https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there
# https://nplus1.ru/blog/2021/03/17/russian-hajj
# https://nplus1.ru/blog/2021/03/16/russian-small-towns
# https://nplus1.ru/blog/2021/03/04/mesmerism-and-the-end-of-the-enlightenment
# https://nplus1.ru/blog/2021/03/02/astronomer-Subbotina
# https://nplus1.ru/blog/2021/03/02/march-2021-observations
# https://nplus1.ru/blog/2021/03/01/freezing-warming
# https://nplus1.ru/blog/2021/02/26/arctic-ice
# https://nplus1.ru/blog/2021/02/26/the-undercover-economist
# https://nplus1.ru/blog/2021/03/22/contrtaunt
# /news/2021/03/29/ever-given
# /news/2021/03/29/insect-plant-gene
# /news/2021/03/27/new-horizons-new-objects
# /news/2021/03/27/teeth-cold-pain
# /news/2021/03/27/encelad-ocean-circulation
# /news/2021/03/27/apophis
# /news/2021/03/27/prigglitz-gasteil
# /material/2021/03/28/degray-eagle-killings
# /rubric/ecology
# /material/2021/03/28/future-with-microsoft-1
# /rubric/partners
# /news/2021/03/26/rover-goes-worldwide
# /news/2021/03/26/leopards-mother-with-three-cubs
# /news/2021/03/26/rabbits-on-forelimbs
# /news/2021/03/26/digit
# /news/2021/03/26/elephants-in-trouble
# /news/2021/03/26/ssb-neurons
# /blog/2021/03/22/contrtaunt
# /blog/2021/03/18/tleilaxu-clones-almost-there
# /material/2021/03/26/gulfstream-and-freezing-europe
# /rubric/ecology
# /theme/spcweather
# /material/2021/03/24/covid-vs-flu
# /rubric/medicine
# /theme/coronavirus-history
# /news/2021/03/26/vixen
# /news/2021/03/26/hot-jupiters-new
# /news/2021/03/26/nuna-development
# /news/2021/03/26/angara-a5
# /news/2021/03/26/outflows-young-stars-hubble
# /news/2021/03/25/atomic-clock-comparison
# /blog/2021/03/17/russian-hajj
# /blog/2021/03/16/russian-small-towns
# /material/2021/03/23/worldnaturephotographyawards2020
# /theme/bellezza
# /material/2021/03/19/how-do-you-want-your-eggs
# /rubric/partners
# /news/2021/03/23/bremsstrahlung
# /material/2021/03/26/gulfstream-and-freezing-europe
# /news/2021/03/25/clamp-your-rna
# /news/2021/03/24/B-meson-decay
# /news/2021/03/26/ssb-neurons
# /news/2021/03/24/aging-zero
# /news/2021/03/25/atomic-clock-comparison
# /material/2021/03/28/degray-eagle-killings
# /material/2021/03/24/covid-vs-flu
# /news/2021/03/22/flow-lines
# https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there
# https://nplus1.ru/blog/2021/03/18/tleilaxu-clones-almost-there
# https://nplus1.ru/blog/2021/03/17/russian-hajj
# https://nplus1.ru/blog/2021/03/16/russian-small-towns
# https://nplus1.ru/blog/2021/03/04/mesmerism-and-the-end-of-the-enlightenment
# https://nplus1.ru/blog/2021/03/02/astronomer-Subbotina
# https://nplus1.ru/blog/2021/03/02/march-2021-observations
# https://nplus1.ru/blog/2021/03/01/freezing-warming
# https://nplus1.ru/blog/2021/02/26/arctic-ice
# https://nplus1.ru/blog/2021/02/26/the-undercover-economist
# https://nplus1.ru/blog/2021/03/22/contrtaunt
# /
# /about
# /adv
# /rules
# /vacancy
# /difficult
# https://nplus1.ru/personal-data-policy
# #
# https://t.me/nplusone
# http://vk.com/nplusone
# https://www.facebook.com/nplusone
# https://twitter.com/nplusodin
# https://ok.ru/nplus1
# https://soundcloud.com/nplus_1
# /rss

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
    if '/news' in link.get('href'):
        urls.append(link.get('href'))
urls
# Out:
# ['/news/2021/03/29/ever-given',
#  '/news/2021/03/29/insect-plant-gene',
#  '/news/2021/03/27/new-horizons-new-objects',
#  '/news/2021/03/27/teeth-cold-pain',
#  '/news/2021/03/27/encelad-ocean-circulation',
#  '/news/2021/03/27/apophis',
#  '/news/2021/03/27/prigglitz-gasteil',
#  '/news/2021/03/26/rover-goes-worldwide',
#  '/news/2021/03/26/leopards-mother-with-three-cubs',
#  '/news/2021/03/26/rabbits-on-forelimbs',
#  '/news/2021/03/26/digit',
#  '/news/2021/03/26/elephants-in-trouble',
#  '/news/2021/03/26/ssb-neurons',
#  '/news/2021/03/26/vixen',
#  '/news/2021/03/26/hot-jupiters-new',
#  '/news/2021/03/26/nuna-development',
#  '/news/2021/03/26/angara-a5',
#  '/news/2021/03/26/outflows-young-stars-hubble',
#  '/news/2021/03/25/atomic-clock-comparison',
#  '/news/2021/03/23/bremsstrahlung',
#  '/news/2021/03/25/clamp-your-rna',
#  '/news/2021/03/24/B-meson-decay',
#  '/news/2021/03/26/ssb-neurons',
#  '/news/2021/03/24/aging-zero',
#  '/news/2021/03/25/atomic-clock-comparison',
#  '/news/2021/03/22/flow-lines']

# %% [markdown]
# Ссылки, которые у нас есть в списке `urls`, относительные: они неполные, начало ссылки (название сайта) отсутствует. Давайте превратим их в абсолютные ‒ склеим с ссылкой https://nplus1.ru.

# %%
full_urls = []

for u in urls:
    res = 'https://nplus1.ru' + u
    full_urls.append(res) 

full_urls
# Out:
# ['https://nplus1.ru/news/2021/03/29/ever-given',
#  'https://nplus1.ru/news/2021/03/29/insect-plant-gene',
#  'https://nplus1.ru/news/2021/03/27/new-horizons-new-objects',
#  'https://nplus1.ru/news/2021/03/27/teeth-cold-pain',
#  'https://nplus1.ru/news/2021/03/27/encelad-ocean-circulation',
#  'https://nplus1.ru/news/2021/03/27/apophis',
#  'https://nplus1.ru/news/2021/03/27/prigglitz-gasteil',
#  'https://nplus1.ru/news/2021/03/26/rover-goes-worldwide',
#  'https://nplus1.ru/news/2021/03/26/leopards-mother-with-three-cubs',
#  'https://nplus1.ru/news/2021/03/26/rabbits-on-forelimbs',
#  'https://nplus1.ru/news/2021/03/26/digit',
#  'https://nplus1.ru/news/2021/03/26/elephants-in-trouble',
#  'https://nplus1.ru/news/2021/03/26/ssb-neurons',
#  'https://nplus1.ru/news/2021/03/26/vixen',
#  'https://nplus1.ru/news/2021/03/26/hot-jupiters-new',
#  'https://nplus1.ru/news/2021/03/26/nuna-development',
#  'https://nplus1.ru/news/2021/03/26/angara-a5',
#  'https://nplus1.ru/news/2021/03/26/outflows-young-stars-hubble',
#  'https://nplus1.ru/news/2021/03/25/atomic-clock-comparison',
#  'https://nplus1.ru/news/2021/03/23/bremsstrahlung',
#  'https://nplus1.ru/news/2021/03/25/clamp-your-rna',
#  'https://nplus1.ru/news/2021/03/24/B-meson-decay',
#  'https://nplus1.ru/news/2021/03/26/ssb-neurons',
#  'https://nplus1.ru/news/2021/03/24/aging-zero',
#  'https://nplus1.ru/news/2021/03/25/atomic-clock-comparison',
#  'https://nplus1.ru/news/2021/03/22/flow-lines']

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = full_urls[1]

page0 = requests.get(url0)
soup0 = BeautifulSoup(page0.text, 'lxml')

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="ie=edge" http-equiv="x-ua-compatible"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="yes" name="apple-mobile-web-app-capable"/>,
#  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>,
#  <meta content="7991d7eb02d759f05b9050e111a7e3eb" name="wmail-verification"/>,
#  <meta content="2021-03-29" itemprop="datePublished"/>,
#  <meta content="Вера Сысоева" name="mediator_author"/>,
#  <meta content="Полученный фермент помог насекомым нейтрализовать токсичные растительные соединения" name="description"/>,
#  <meta content="Вера Сысоева" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="Биологи впервые обнаружили горизонтальный перенос генов от растения к насекомому" property="og:title"/>,
#  <meta content="https://nplus1.ru/images/2021/03/27/599389f22b8d1c0b82283f28f44d3db0.jpg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2021/03/29/insect-plant-gene" property="og:url"/>,
#  <meta content="Полученный фермент помог насекомым нейтрализовать токсичные растительные соединения" property="og:description"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Биологи впервые обнаружили горизонтальный перенос генов от растения к насекомому" name="twitter:title"/>,
#  <meta content="Полученный фермент помог насекомым нейтрализовать токсичные растительные соединения" name="twitter:description"/>,
#  <meta content="https://nplus1.ru/images/2021/03/27/599389f22b8d1c0b82283f28f44d3db0.jpg" name="twitter:image"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>]

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Вера Сысоева" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Вера Сысоева" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Вера Сысоева'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find_all('meta', {'name' : 'author'})[0].attrs['content']
author
# Out:
# 'Вера Сысоева'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].attrs['content']
title = soup0.find_all('meta', {'property' : 'og:title'})[0].attrs['content']
description = soup0.find_all('meta', {'name' : 'description'})[0].attrs['content']

# %% [markdown]
# Осталось вытащить рубрики и сложность текста. Если мы посмотрим на исходный код страницы, мы увидим, что нужная нам информация находится в тэгах `<p></p>`:

# %%
soup0.find_all('p')
# Out:
# [<p class="table">
#  <a data-rubric="biology" href="/rubric/biology">Биология</a>
#  <a data-rubric="zoology" href="/rubric/zoology">Зоология</a>
#  </p>,
#  <p class="table">
#  <a href="/news/2021/03/29">
#  <time content="2021-03-29" data-unix="1617000532" itemprop="datePublished">
#  <span>09:48</span>
#  <span>29 Март 2021</span>
#  </time>
#  </a>
#  </p>,
#  <p class="table">
#  <a href="/difficult/4.2">
#  <span>Сложность</span>
#  <span class="difficult-value">4.2</span>
#  </a>
#  </p>,
#  <p class="title"></p>,
#  <p class="credits">Jixing Xia et al. / Cell, 2021</p>,
#  <p>Китайские биологи описали первый известный пример горизонтального переноса генов от растения к насекомому. Оказалось, табачные белокрылки (<i>Bemisia tabaci</i>) присвоили себе растительный ген. Синтезируемый с помощью этого гена фермент позволяет насекомым нейтрализовать яд, призванный защищать растения, поэтому на этих насекомых-вредителей не влияют растительные токсины. Работа <a href="https://doi.org/10.1016/j.cell.2021.02.014" rel="nofollow" target="_blank">опубликована</a> в <i>Cell</i>.</p>,
#  <p>За более чем 400 миллионов лет <a href="https://books.google.ru/books?hl=en&amp;lr=&amp;id=3FNuALVdArYC&amp;oi=fnd&amp;pg=PR5&amp;ots=_MgXIa9keE&amp;sig=Dxwvd-UvBKAPkXw0-LqP0CelXwc&amp;redir_esc=y#v=onepage&amp;q&amp;f=false" rel="nofollow" target="_blank">сосуществования</a> с травоядными животными растения научились защищаться: какие-то <a href="https://www.nature.com/articles/s41477-019-0505-x" rel="nofollow" target="_blank">изменили</a> свою морфологию (например, изменили форму листьев), другие же <a href="https://www.annualreviews.org/doi/10.1146/annurev-arplant-042110-103854" rel="nofollow" target="_blank">применили</a> биохимические способы отражать атаки насекомых.</p>,
#  <p>Фенольные гликозиды – группа соединений, состоящих из углеводного остатка и фенольной группы – одни из самых распространенных метаболитов растений, которые могут <a href="https://www.sciencedirect.com/science/article/abs/pii/S0031942211000677" rel="nofollow" target="_blank">влиять</a> на рост, развитие и поведение насекомых. Самим растениям эти соединения не опасны: они при помощи фермента малонилтрансферазы <a href="https://onlinelibrary.wiley.com/doi/full/10.1111/j.1365-313X.2010.04298.x" rel="nofollow" target="_blank">присоединяют</a> к гликозидам малониловую группу, в результате фенольные гликозиды теряют свою токсичность.</p>,
#  <p>Некоторые насекомые, однако, не испытывают негативных последствий от попадания фенольных гликозидов в их организм вместе с пищей: наоборот, они научились использовать их как питательные вещества и стимуляторы кладки яиц. Представители вида табачная белокрылка (<i>Bemisia tabaci</i>) – распространенные насекомые-вредители. <i>B. tabaci</i> <a href="https://www.annualreviews.org/doi/10.1146/annurev-virology-031413-085410" rel="nofollow" target="_blank">питаются</a> флоэмой растений, проводящей тканью, по которой продукты фотосинтеза – питательные вещества – поступают к корням, цветкам, плодам. Белокрылки переносят растительные вирусы и в целом сильно снижают урожайность. При этом вредители могут питаться более чем 600 видами растений – и прекрасно <a href="https://www.sciencedirect.com/science/article/abs/pii/S0261219401001089" rel="nofollow" target="_blank">адаптируются</a> к защитным механизмам всех этих видов. Большинство из этих растений как раз используют фенольные гликозиды как способ биохимической защиты. <i>Bemisia tabaci</i> нейтрализуют эти соединения при помощи ферментов, однако как именно им удается обойти отличающиеся друг от друга защитные приспособления стольких растений, оставалось неизвестным. </p>,
#  <p>Ученые Китайской академии агрокультурных наук под руководством Юцзюнь Чжана (Youjun Zhang) провели биоинформатический анализ и обнаружили в геноме насекомых <u><i></i></u><i>B. tabaci</i><u></u> ген малонилтрансферазы, который, по-видимому, и помогает насекомым нейтрализовать действие фенольных гликозидов. Дальнейшие исследования показали, что ближайшие гомологи этого гена есть у растений, но не у членистоногих. Ученые пришли к выводу, что что в геном насекомых<i> B. tabaci</i> попал специфичный для растений ген <i>BtPMaT1</i>. Этот ген экспрессируется у насекомых на всех стадиях развития, но больше всего во взрослом возрасте, и особенно в желудке.</p>,
#  <p>Исследователи решили проверить, спасает ли растительный ген насекомых от воздействия фенольных гликозидов. Из листьев томата биологи выделили 11 соединений этой группы. Пять из них оказались ядовитыми<i> B. tabaci</i>, а шесть – не причинили вреда. При этом концентрации веществ (10 микромоль) в эксперименте были намного выше, чем те, которые получают насекомые в природе с пищей. Когда ученые снизили экспрессию гена <i>BtPMaT1</i> на 49,2 процента, пять «нетоксичных» гликозидов повысили смертность насекомых. </p>,
#  <p>Эксперименты<i> in vitro</i> на клеточных культурах показали, что белок BtPMaT1 действительно обладает малонилтрансферазной активностью в отношении трех из одиннадцати протестированных фенольных гликозидов. Под действием BtPMaT1, эти соединения превратились в соответствующие малонилгликозиды. Схожие результаты были получены и в экспериментах на насекомых, которых кормили листьями томатов.</p>,
#  <p>Наконец, ученые проверили, можно ли повысить устойчивость растений к белокрылкам. Исследователи создали трансгенный томат, в геном которого вставили участки ДНК, кодирующие образующие шпильки малые молекулы РНК. Шпильки из РНК позволяют подавлять экспрессию того или иного гена, в этой работе ученые нацелили их на <i>BtPMaT1</i>. Смертность у насекомых, которым дали листьями таких томатов, повысилась уже на первый день кормления. В условиях, имитирующих полевые, транспортные томаты привели к смерти почти 100 процентов белокрылок, тогда как в контрольной группе смертность составила только 20 процентов.</p>,
#  <p>Исследование раскрывает необычный эволюционный путь, благодаря которому табачные белокрылки смогли применить растительный ген для нейтрализации растительного же токсина. До этого были <a href="https://academic.oup.com/gbe/article/8/6/1785/2574079" rel="nofollow" target="_blank">известны</a>  примеры горизонтального переноса генов членистоногим только от микроорганизмов. Показанный же в этой работе горизонтальный перенос растительного гена наделил насекомых способностью питаться многими растениями, не опасаясь фенольных гликозидов. </p>,
#  <p>Горизонтальный перенос генов – естественный процесс, когда один организм передает генетический материал не своему потомку. Получить чужую ДНК очень непросто, и о том, как это происходит, может прочитать в материале <a href="https://nplus1.ru/material/2019/01/28/pass-me-gene-please" target="_blank">«Поверх барьеров»</a>.</p>,
#  <p><i>Вера Сысоева</i></p>,
#  <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>,
#  <p class="subtitle">Биологи четверть века искали убийцу орланов в Арканзасе — и, наконец, нашли</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>© 2021 N+1 Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614</p>,
#  <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.
#                          Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                          только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                          и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>,
#  <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>,
#  <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>,
#  <p>
#  <a class="pd" href="https://nplus1.ru/personal-data-policy">Политика обработки персональных данных пользователей сайта</a>
#  </p>,
#  <p>
#  <script async="" src="//s.luxupcdnc.com/t/consent_195458.js" type="text/javascript"></script>
#  <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#  </p>,
#  <p>
#  </p>]

# %% [markdown]
# Выберем из полученного списка первый элемент и найдем в нем все тэги `<a>`:

# %%
soup0.find_all('p')[0].find_all('a')
# Out:
# [<a data-rubric="biology" href="/rubric/biology">Биология</a>,
#  <a data-rubric="zoology" href="/rubric/zoology">Зоология</a>]

# %% [markdown]
# Получился список из одного элемента. Применим списковые включения – вытащим из каждого элемента (их могло бы быть больше) текст и поместим его в новый список `rubrics`.

# %%
rubrics = [r.text for r in soup0.find_all('p')[0].find_all('a')]
rubrics
# Out:
# ['Биология', 'Зоология']

# %% [markdown]
# Осталась только сложность. Возьмем соответствующий кусок кода:

# %%
soup0.find_all('span', {'class' : 'difficult-value'})
# Out:
# [<span class="difficult-value">4.2</span>]

# %% [markdown]
# И выберем оттуда текст.

# %%
diff = soup0.find_all('span', {'class' : 'difficult-value'})[0].text
diff
# Out:
# '4.2'

# %% [markdown]
# Теперь перейдем к тексту самой новости. Как можно заметить, текст сохранен в абзацах `<p></p>`, причем безо всяких атрибутов. Сообщим Python, что нас интересуют куски с пустым атрибутом `class`:

# %%
text_list = soup0.find_all('p', {'class' : None})

# %% [markdown]
# «Выцепим» все тексты (без тэгов) из полученного списка:

# %%
text = [t.text for t in text_list]

# %% [markdown]
# Склеим все элементы списка `text` через пробел:

# %%
final_text = ' '.join(text)
final_text
# Out:
# 'Китайские биологи описали первый известный пример горизонтального переноса генов от растения к насекомому.\xa0Оказалось, табачные белокрылки (Bemisia tabaci) присвоили себе растительный ген.\xa0Синтезируемый с помощью этого гена фермент позволяет насекомым нейтрализовать яд, призванный защищать растения, поэтому на этих насекомых-вредителей не влияют растительные токсины.\xa0Работа опубликована\xa0в Cell. За более чем 400 миллионов лет сосуществования с травоядными животными растения научились защищаться: какие-то изменили\xa0свою морфологию (например, изменили форму листьев), другие же применили\xa0биохимические способы отражать атаки насекомых. Фенольные гликозиды – группа соединений, состоящих из углеводного остатка и фенольной группы – одни из самых распространенных метаболитов растений, которые могут влиять\xa0на рост, развитие и поведение насекомых. Самим растениям эти соединения не опасны: они при помощи фермента малонилтрансферазы присоединяют\xa0к гликозидам малониловую группу, в результате фенольные гликозиды теряют свою токсичность. Некоторые насекомые, однако, не испытывают негативных последствий от попадания фенольных гликозидов в их организм вместе с пищей: наоборот, они научились использовать их как питательные вещества и стимуляторы кладки яиц. Представители вида табачная белокрылка (Bemisia tabaci) – распространенные насекомые-вредители. B. tabaci питаются\xa0флоэмой растений, проводящей тканью, по которой продукты фотосинтеза – питательные вещества – поступают к корням, цветкам, плодам. Белокрылки переносят растительные вирусы и в целом сильно снижают урожайность. При этом вредители могут питаться более чем 600 видами растений – и прекрасно адаптируются\xa0к защитным механизмам всех этих видов. Большинство из этих растений как раз используют фенольные гликозиды как способ биохимической защиты. Bemisia tabaci нейтрализуют эти соединения при помощи ферментов, однако как именно им удается обойти отличающиеся друг от друга защитные приспособления стольких растений, оставалось неизвестным.\xa0 Ученые Китайской академии агрокультурных наук под руководством Юцзюнь Чжана (Youjun Zhang) провели биоинформатический анализ и обнаружили в геноме насекомых B. tabaci ген малонилтрансферазы, который, по-видимому, и помогает насекомым нейтрализовать действие фенольных гликозидов. Дальнейшие исследования показали, что ближайшие гомологи этого гена есть у растений, но не у членистоногих. Ученые пришли к выводу, что что в геном насекомых B. tabaci попал специфичный для растений ген BtPMaT1. Этот ген экспрессируется у насекомых на всех стадиях развития, но больше всего во взрослом возрасте, и особенно в желудке. Исследователи решили проверить, спасает ли растительный ген насекомых от воздействия фенольных гликозидов. Из листьев томата биологи выделили 11 соединений этой группы. Пять из них оказались ядовитыми B. tabaci, а шесть – не причинили вреда. При этом концентрации веществ (10 микромоль) в эксперименте были намного выше, чем те, которые получают насекомые в природе с пищей. Когда ученые снизили экспрессию гена\xa0BtPMaT1 на 49,2 процента, пять «нетоксичных» гликозидов повысили смертность насекомых.\xa0 Эксперименты in vitro на клеточных культурах показали, что белок BtPMaT1 действительно обладает малонилтрансферазной активностью в отношении трех из одиннадцати протестированных фенольных гликозидов. Под действием BtPMaT1, эти соединения превратились в соответствующие малонилгликозиды. Схожие результаты были получены и в экспериментах на насекомых, которых кормили листьями томатов. Наконец, ученые проверили, можно ли повысить устойчивость растений к белокрылкам. Исследователи создали трансгенный томат, в геном которого вставили участки ДНК, кодирующие образующие шпильки малые молекулы РНК. Шпильки из РНК позволяют подавлять экспрессию того или иного гена, в этой работе ученые нацелили их на BtPMaT1. Смертность у насекомых, которым дали листьями таких томатов, повысилась уже на первый день кормления. В условиях, имитирующих п ...

# %% [markdown]
# Все здорово, только мешают отступы-переходы на новую строку `\n`. Заменим их на пробелы с помощью метода `.replace`:

# %%
final_text = final_text.replace('\n', ' ')

# %%
final_text = final_text.replace('\xa0', ' ')

# %%
final_text
# Out:
# 'Китайские биологи описали первый известный пример горизонтального переноса генов от растения к насекомому. Оказалось, табачные белокрылки (Bemisia tabaci) присвоили себе растительный ген. Синтезируемый с помощью этого гена фермент позволяет насекомым нейтрализовать яд, призванный защищать растения, поэтому на этих насекомых-вредителей не влияют растительные токсины. Работа опубликована в Cell. За более чем 400 миллионов лет сосуществования с травоядными животными растения научились защищаться: какие-то изменили свою морфологию (например, изменили форму листьев), другие же применили биохимические способы отражать атаки насекомых. Фенольные гликозиды – группа соединений, состоящих из углеводного остатка и фенольной группы – одни из самых распространенных метаболитов растений, которые могут влиять на рост, развитие и поведение насекомых. Самим растениям эти соединения не опасны: они при помощи фермента малонилтрансферазы присоединяют к гликозидам малониловую группу, в результате фенольные гликозиды теряют свою токсичность. Некоторые насекомые, однако, не испытывают негативных последствий от попадания фенольных гликозидов в их организм вместе с пищей: наоборот, они научились использовать их как питательные вещества и стимуляторы кладки яиц. Представители вида табачная белокрылка (Bemisia tabaci) – распространенные насекомые-вредители. B. tabaci питаются флоэмой растений, проводящей тканью, по которой продукты фотосинтеза – питательные вещества – поступают к корням, цветкам, плодам. Белокрылки переносят растительные вирусы и в целом сильно снижают урожайность. При этом вредители могут питаться более чем 600 видами растений – и прекрасно адаптируются к защитным механизмам всех этих видов. Большинство из этих растений как раз используют фенольные гликозиды как способ биохимической защиты. Bemisia tabaci нейтрализуют эти соединения при помощи ферментов, однако как именно им удается обойти отличающиеся друг от друга защитные приспособления стольких растений, оставалось неизвестным.  Ученые Китайской академии агрокультурных наук под руководством Юцзюнь Чжана (Youjun Zhang) провели биоинформатический анализ и обнаружили в геноме насекомых B. tabaci ген малонилтрансферазы, который, по-видимому, и помогает насекомым нейтрализовать действие фенольных гликозидов. Дальнейшие исследования показали, что ближайшие гомологи этого гена есть у растений, но не у членистоногих. Ученые пришли к выводу, что что в геном насекомых B. tabaci попал специфичный для растений ген BtPMaT1. Этот ген экспрессируется у насекомых на всех стадиях развития, но больше всего во взрослом возрасте, и особенно в желудке. Исследователи решили проверить, спасает ли растительный ген насекомых от воздействия фенольных гликозидов. Из листьев томата биологи выделили 11 соединений этой группы. Пять из них оказались ядовитыми B. tabaci, а шесть – не причинили вреда. При этом концентрации веществ (10 микромоль) в эксперименте были намного выше, чем те, которые получают насекомые в природе с пищей. Когда ученые снизили экспрессию гена BtPMaT1 на 49,2 процента, пять «нетоксичных» гликозидов повысили смертность насекомых.  Эксперименты in vitro на клеточных культурах показали, что белок BtPMaT1 действительно обладает малонилтрансферазной активностью в отношении трех из одиннадцати протестированных фенольных гликозидов. Под действием BtPMaT1, эти соединения превратились в соответствующие малонилгликозиды. Схожие результаты были получены и в экспериментах на насекомых, которых кормили листьями томатов. Наконец, ученые проверили, можно ли повысить устойчивость растений к белокрылкам. Исследователи создали трансгенный томат, в геном которого вставили участки ДНК, кодирующие образующие шпильки малые молекулы РНК. Шпильки из РНК позволяют подавлять экспрессию того или иного гена, в этой работе ученые нацелили их на BtPMaT1. Смертность у насекомых, которым дали листьями таких томатов, повысилась уже на первый день кормления. В условиях, имитирующих полевые, транспортные томаты привели к с ...

# %% [markdown]
# Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Returns a tuple with url0, date, author, description, title, final_text, rubrics, diff.
    Parameters:
    
    url0 is a link to the news (string)
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'lxml')
    author = soup0.find_all('meta', {'name' : 'author'})[0].attrs['content']
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].attrs['content']
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].attrs['content']
    description = soup0.find_all('meta', {'name' : 'description'})[0].attrs['content']
    rubrics = [r.text for r in soup0.find_all('p')[0].find_all('a')]
    diff = soup0.find_all('span', {'class' : 'difficult-value'})[0].text
    text_list = soup0.find_all('p', {'class' : None})
    text = [t.text for t in text_list]
    final_text = ' '.join(text)
    final_text = final_text.replace('\n', ' ')
    final_text = final_text.replace('\xa0', ' ')
    
    return url0, date, author, description, title, final_text, rubrics, diff

# %% [markdown]
# Уфф. Осталось применить ее в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится. Приступим.

# %%
from time import sleep

# %%
news = [] # это будет список из кортежей, в которых будут храниться данные по каждой новости

for link in full_urls:
    res = GetNews(link)
    news.append(res)
    sleep(5) # задержка в 5 секунд

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %%
news[0]
# Out:
# ('https://nplus1.ru/news/2021/03/29/ever-given',
#  '2021-03-29',
#  'Василий Сычев',
#  'Судно перекрывало Суэцкий канал шесть дней',
#  'Контейнеровоз «Эвер Гивен» удалось сдвинуть с места',
#  'Службе Суэцкого канала удалось снять с мели кормовую часть контейнеровоза «Эвер Гивен» типа «Голден», принадлежащего тайваньской компании Evergreen Marine и имеющего панамскую регистрацию. Как сообщает CNN, в настоящее время буксиры пытаются освободить носовую часть судна, после чего «Эвер Гивен» выведут на фарватер. Как ожидается, контейнеровоз полностью снимут с мели до конца 29 марта 2021 года. Команда «Эвер Гивен» уже запустила двигатели контейнеровоза. Как ожидается, после снятия носовой части контейнеровоза с мели, специалисты проведут техническую инспекцию судна, после чего оно продолжит движение, а Суэцкий канал откроют для прохода скопившихся на входах более чем 300 судов. После снятия с мели буксиры для подстраховки сопроводят «Эвер Гивен» до Большого Горького озера, расположенного между южной и северной частями Суэцкого канала. «Эвер Гивен» был построен в 2018 году в Японии судостроительной компанией Imabari Shipbuilding. Контейнеровоз имеет 400 метров в длину и 58,8 метра в ширину. Судно с осадкой 16 метров рассчитано на перевозку 20,1 тысячи стандартных 20-футовых морских контейнеров (длина 6,1 метра, ширина 2,44 метра и высота 2,59 метра). Дедвейт судна составляет 199,5 тысячи тонн. Крейсерская скорость «Эвер Гивен» составляет 9,6 узла (17,7 километра в час).  24 марта 2021 года при проходе через Суэцкий канал судно село на мель. Основной причиной произошедшего компания Evergreen Marine называет сильный порыв ветра, из-за которого контейнеровоз отклонился от курса, после чего носовой и кормовой частями сел на мель, перекрыв судоходный канал. На протяжении почти недели снять судно с мели пытались до десяти буксиров. Под контейнеровозом были проведены дноуглубительные работы. Прохождение судоходных каналов большими судами сопряжено с несколькими сложностями. В частности, такие суда могут столкнуться с эффектом смещения с курса. Особенно сильно он проявляется при превышении скорости. В этом случае в носовой части судна со стороны, ближайшей к берегу, во время движения повышается уровень воды (судно, как поршень, гонит воду перед собой) и ее давление. В результате носовую часть начинает отталкивать от берега. Одновременно в кормовой части уровень и давление воды со стороны стенки канала падают, и возникает эффект присасывания. Как итог, судно очень быстро теряет прямолинейность движения. Вероятно, это произошло с «Эвер Гивен». Судя по записи параметров движения судна по каналу, из-за эффектов отталкивания и присасывания «Эвер Гивен» начало «бросать» по всей ширине Суэцкого канала, пока контейнеровоз не встал по диагонали. Василий Сычёв Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter. Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности © 2021 N+1 Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614 Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N+1.                          Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются                          только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения                          и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции. Сайт может содержать контент, не предназначенный для лиц младше 18 лет.  Политика обработки персональных данных пользователей сайта    Change privacy settings   ',
#  ['Мезонин', 'Транспорт'],
#  '3.1')
