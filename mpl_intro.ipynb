# %% [markdown]
# Пакет `matplotlib` - это библиотека, предназначенная для построения двумерных диаграмм и графиков. Она не является частью стандартной библиотеки Python, но входит в состав дистрибутива [Anaconda](https://docs.anaconda.com/anaconda/packages/py3.7_win-64/).

# %% [markdown]
# В интерактивном режиме для проверки введите команду:
#
# ```Python
# import matplotlib
# ```

# %% [markdown]
# Пакет `matplotlib` содержит модуль `pyplot`, который необходимо импортировать для создания графиков (используем псевдоним `plt`):
#
# ```Python
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# ## 1. Создание линейного графика

# %% [markdown]
# Функция `plot` используется для создания линейного графика, который соединяет серию точек данных отрезками прямой. Линейный график имеет горизонтальную ось `х` и вертикальную ось `у`. Каждая точка данных на графике имеет координаты `(Х, Y)`. Для того чтобы создать линейный график, сначала необходимо создать два списка: один с координатами `x` каждой точки данных и другой с координатами `У` каждой точки данных.
#
# Предположим, есть пять точек данных, расположенных в приведенных ниже координатах:
#
# ```Python
# (0, 0), (2, 3), (3, 1), (4 , 5), (6, 1)
# ```
#
# Создаем два списка, которые будут содержать эти координаты:
#
# ```Python
# х_coords = [0, 2, 3, 4, 6]
# y_coords = [0, 3, 1, 5, 1]
# ```

# %%
# Эта программа выводит простой линейный график.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать списки для координат X и Y каждой точки данных.
x_coords = [0, 2, 3, 4, 6]
y_coords = [0, 3, 1, 5, 1]

# Построить линейный график.
plt.plot(x_coords, y_coords)

# Показать линейный график.
plt.show()

# %% [markdown]
# При помощи функции `title` можно добавлять в график заголовок. Заголовок будет выведен чуть выше графика.
# Кроме того, при помощи функций `ylabel` и `xlabel` можно добавить описательные метки на оси `х` и `у`.
# В график можно добавить сетку, вызвав для этого функцию `grid(True)`.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать списки для координат X и Y каждой точки данных.
x_coords = [0, 2, 3, 4, 6]
y_coords = [0, 3, 1, 5, 1]

# Построить линейный график.
plt.plot(x_coords, y_coords)

# Добавить заголовок.
plt.title('Образец данных')

# Добавить на оси описательные метки.
plt.xlabel('Это ось X')
plt.ylabel('Это ось Y')

# Добавить сетку.
plt.grid(True)

# Показать линейный график.
plt.show()

# %% [markdown]
# По умолчанию ось `х` начинается в самой нижней координате `Х` и заканчивается в самой верхней координате `Х` набора точек данных. Например, обратите внимание, что самая нижняя координата `Х` равняется `О`, а самая верхняя координата `Х` равняется `5`.
#
# Ось `у` по умолчанию сконфигурирована таким же образом.
#
# Нижние и верхние границы осей `х` и `у` можно изменить, вызвав функции `ylim` и `xlim` например,
# ```Python
# plt.xlim(xmin=1, xmax=100)
# ```
# Эта инструкция конфигурирует ось `х` так, чтобы она начиналась в значении `1`
# и заканчивалась в значении `100`.
#
# Аналогично по оси `у`:
# ```Python
# plt.ylim(ymin=10, ymax=50)
# ```

# %%
# Эта программа выводит простой линейный график.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать списки для координат X и Y каждой точки данных.
x_coords = [0, 2, 3, 4, 6]
y_coords = [0, 3, 1, 5, 1]

# Построить линейный график.
plt.plot(x_coords, y_coords)

# Добавить заголовок.
plt.title('Образец данных')

# Добавить на оси описательные метки.
plt.xlabel('Это ось X')
plt.ylabel('Это ось Y')

# Задать границы осей.
plt.xlim(xmin=-1, xmax=5)
plt.ylim(ymin=-1, ymax=6)

# Добавить сетку.
plt.grid(True)

# Показать линейный график.
plt.show()

# %% [markdown]
# Каждую подпись метки деления можно индивидуально настроить при помощи функций
# `yticks` и `xticks`. Эти функции в качестве аргументов принимают два списка. Первый аргумент - это список позиций меток, а второй аргумент - список подписей для вывода в указанных позициях.

# %%
# Эта программа выводит простой линейный график.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать списки для координат X и Y каждой точки данных.
x_coords = [0, 2, 3, 4, 6]
y_coords = [0, 3, 1, 5, 1]

# Построить линейный график.
plt.plot(x_coords, y_coords)

# Добавить заголовок.
plt.title('Продажи с разбивкой по годам')

# Добавить на оси описательные метки.
plt.xlabel('Год')
plt.ylabel('Объем продаж')

# Настроить метки делений.
plt.xticks([0, 1, 2, 3, 4, 5, 6],
           ['2016', '2017', '2018', '2019', '2020', '2021', '2022'])
plt.yticks([0, 1, 2, 3, 4, 5],
           ['0m', '1m', '2m', '3m', '4m', '5m'])

# Добавить сетку.
plt.grid(True)

# Показать линейный график.
plt.show()

# %% [markdown]
# В каждой точке данных на линейной диаграмме можно вывести круглую метку в качестве маркера, применяя функцию `plot` вместе с именованным аргументом `marker='o'`.

# %%
# Эта программа выводит простой линейный график.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать списки для координат X и Y каждой точки данных.
x_coords = [0, 2, 3, 4, 6]
y_coords = [0, 3, 1, 5, 1]

# Построить линейный график.
plt.plot(x_coords, y_coords, marker='o') # 'o'

# https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.plot.html

# Добавить заголовок.
plt.title('Продажи с разбивкой по годам')

# Добавить на оси описательные метки.
plt.xlabel('Год')
plt.ylabel('Объем продаж')

# Настроить метки делений.
plt.xticks([0, 1, 2, 3, 4],
           ['2016', '2017', '2018', '2019', '2020'])
plt.yticks([0, 1, 2, 3, 4, 5],
           ['0m', '1m', '2m', '3m', '4m', '5m'])

# Добавить сетку.
plt.grid(True)

# Показать линейный график.
plt.show()

# %% [markdown]
# ## Несколько графиков

# %%
# Эта программа выводит простой линейный график.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать списки для координат X и Y каждой точки данных.
x1 = [0, 2, 3, 4, 12]
y1 = [0, 3, 1, 5, 3]
x2 = [0, 5, 7, 10, 12]
y2 = [0, 2, 3, 4, 6]

# Построить линейный график.
plt.plot(x1, y1, x2, y2)

# Показать линейный график.
plt.show()

# %%
## 2. Построение столбчатой диаграммы

# %% [markdown]
# Функция `bar` в модуле `matplotlib.pyplot` применяется для создания столбчатой диаграммы.
#
# Столбчатая диаграмма имеет горизонтальную ось `х`, вертикальную ось `у` и серию прямоугольных столбиков, которые, как правило, исходят из оси `х`. Каждый прямоугольный столбик представляет значение, а высота столбика пропорциональна этому значению.
#
# Сначала создаются два списка: один содержит координаты `Х` левого края каждого прямоугольного столбика, а другой - высоту каждого столбика вдоль оси `у`.
#
# В программе создается список `left_edges`, который содержит координаты `Х` левого края каждого столбика.
#
# Затем создается список `heights`, который содержит высоту каждого столбика.

# %%
# Эта программа выводит простую столбчатую диаграмму.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать список с координатами X левого края каждого столбика
left_edges = [0, 10, 20, 30, 40]

# Создать список с высотами каждого столбика.
heights = [100, 200, 300, 400, 500]

# Построить столбчатую диаграмму.
plt.bar(left_edges, heights)

# Построить столбчатую диаграмму.
plt.show()

# %% [markdown]
# По умолчанию ширина каждого столбика на столбчатой диаграмме равняется `0.8`
# вдоль оси `х`. Ширину столбика можно изменить, передав в функцию `bar` третий аргумент.

# %%
# Эта программа выводит простую столбчатую диаграмму.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать список с координатами X левого края каждого столбика
left_edges = [0, 10, 20, 30, 40]

# Создать список с высотами каждого столбика.
heights = [100, 200, 300, 400, 500]

# Создать переменную для ширины столбика.
bar_width = 5

# Построить столбчатую диаграмму.
plt.bar(left_edges, heights, bar_width)

# Показать столбчатую диаграмму.
plt.show()

# %% [markdown]
# Цвет можно задать, указав в функции `bar` именованный параметр `color`.

# %% [markdown]
# ![](https://matplotlib.org/3.1.0/_images/sphx_glr_named_colors_001.png)

# %% [markdown]
# По аналогии с линейным графиком можно индивидуально определить оси `x` и `y`.

# %%
# Эта программа выводит диаграмму объема продаж.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать список с координатами X левого края каждого столбика.
left_edges = [0, 10, 20, 30, 40]

# Создать список с высотами каждого столбика.
heights = [100, 200, 300, 400, 500]

# Создать переменную для ширины столбика.
bar_width = 10

# Построить столбчатую диаграмму.
plt.bar(left_edges, heights, bar_width, 
        color=('r', 'g', 'b', 'm', 'k'))

# Добавить заголовок.
plt.title('Продажи с разбивкой по годам')

# Добавить на оси описательные метки.
plt.xlabel('Год')
plt.ylabel('Объем продаж')

# Настроить метки делений.
plt.xticks([5, 15, 25, 35, 45],
           ['2016', '2017', '2018', '2019', '2020'])
plt.yticks([0, 100, 200, 300, 400, 500],
           ['0m', '1m', '2m', '3m', '4m', '5m'])

# Показать столбчатую диаграмму.
plt.show()

# %% [markdown]
# ### Дополнительно:
#
# Много разных (более сложных) примеров `barplot`: http://python-graph-gallery.com/barplot/

# %% [markdown]
# ## 3. Построение круговой диаграммы

# %% [markdown]
# **Круговая диаграмма** - это график, который показывает круг, поделенный на доли. Круг представляет целое, а секторы - процентное содержание целого.
#
# Для создания круговой диаграммы используется функция `pie` из модуля `matplotlib.pyplot`.
#
# Когда вызывается функция `pie`, ей в качестве аргумента передается список значений. Функция `pie` вычисляет сумму значений в списке и затем использует эту сумму в качестве значения целого. Затем каждый элемент в списке станет сектором (долей) в круговой диаграмме.
#
# Размер сектора представляет значение этого элемента как процентное содержание целого.

# %%
# Эта программа выводит простую круговую диаграмму.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать список значений
values = [20, 60, 80, 40]

# Создать из этих значений круговую диаграмму.
plt.pie(values)

# Показать круговую диаграмму.
plt.show()

# %% [markdown]
# Функция `pie` имеет параметр `labels`, который можно использовать для отображения меток долей на круговой диаграмме. Аргумент, который передается в этот параметр, является списком, содержащим нужные метки в качестве строк.

# %%
# Эта программа выводит простую круговую диаграмму.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать список объемов продаж.
sales = [100, 400, 300, 600]

# Создать список меток долей.
slice_labels = ['1-й кв', '2-й кв', '3-й кв', '4-й кв']

# Создать из этих значений круговую диаграмму.
plt.pie(sales, labels=slice_labels)

# Добавить заголовок.
plt.title('Продажи с разбивкой по кварталам')

# Показать круговую диаграмму.
plt.show()

# %% [markdown]
# Функция `pie` автоматически меняет цвет долей в следующем порядке: синий, зеленый, красный, голубой, сиреневый, желтый, черный и белый. Однако имеется возможность определить другой набор цветов, передав в параметр `colors` функции `pie` кортеж цветовых кодов в качестве аргумента.

# %%
# Эта программа выводит простую круговую диаграмму.
import matplotlib.pyplot as plt
# %matplotlib inline

# Создать список объемов продаж.
sales = [100, 400, 300, 600]

# Создать список of меток долей.
slice_labels = ['1-й кв', '2-й кв', '3-й кв', '4-й кв']

# Создать из этих значений круговую диаграмму.
plt.pie(sales, labels=slice_labels, colors=('r', 'g', 'b', 'm', 'k'))

# Добавить заголовок.
plt.title('Продажи с разбивкой по кварталам')

# Показать круговую диаграмму.
plt.show()
